# %%
import networkx as nx
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
import numpy as np
from ensemble_to_object import Density_object

# %%
def _compute_orbital_mockup(self):
    '''
    '''
    for index in self.reactive_indexes:
        if self.atomcoords[0][index]:
# Out:
#   File "<ipython-input-3-d5c9c6bd9eac>", line 1
#     def _compute_orbital_mockup(self):
#                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
mol = Chem.MolFromMolFile('Resources/funky_single.mol')
matrix = Chem.GetAdjacencyMatrix(mol)
graph = nx.from_numpy_matrix(matrix)
nx.draw(graph, with_labels=True)

# %%
atom_type_dict = {
            #  '1':'single',
             'C2':'sp',
             'C3':'sp2',
             'C4':'sp3',
             'N2':'imine',
             'N3':'amine',
             'N4':'sp3',
             'O2':'ether', # or alcohol
             'S2':'ether',
             }

mol = Chem.AddHs(mol)
for atom in mol.GetAtoms():
    symbol = atom.GetSymbol()
    neighbors = len(atom.GetNeighbors())
    # if neighbors == 1:
    #     atom_type = 'single'
    # else:
    #     atom_type = atom_type_dict[symbol + str(neighbors)]

    print(atom.GetIdx(), symbol, atom.GetBonds())
# Out:
# 0 C (<rdkit.Chem.rdchem.Bond object at 0x00000298D59457B0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5ADEBC0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9850>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9710>)
# 1 C (<rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9710>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9800>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE93A0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE97B0>)
# 2 C (<rdkit.Chem.rdchem.Bond object at 0x00000298D59457B0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5ADEBC0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9850>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE97B0>)
# 3 C (<rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9710>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE93A0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9800>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE97B0>)
# 4 C (<rdkit.Chem.rdchem.Bond object at 0x00000298D59457B0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5ADEBC0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9850>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE97B0>)
# 5 C (<rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9710>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9800>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE93A0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE97B0>)
# 6 O (<rdkit.Chem.rdchem.Bond object at 0x00000298D59457B0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5ADEBC0>)
# 7 N (<rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9710>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE93A0>, <rdkit.Chem.rdchem.Bond object at 0x00000298D5BE9800>)
# 8 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960DF0>,)
# 9 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960EE0>,)
# 10 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960DF0>,)
# 11 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960EE0>,)
# 12 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960DF0>,)
# 13 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960EE0>,)
# 14 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960DF0>,)
# 15 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960EE0>,)
# 16 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960DF0>,)
# 17 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960EE0>,)
# 18 H (<rdkit.Chem.rdchem.Bond object at 0x00000298D5960DF0>,)
